# %% [markdown]
# # Cats vs Dogs

# %% [markdown]
# # I. Analyse exploratoire

# %% [markdown]
# ## 1. Libraries and data

# %%
# %load_ext autoreload
# %autoreload 2
import torch
import torch.nn as nn
import os
import matplotlib.pyplot as plt 
import matplotlib.image as img
from utils.dataset import DogCatDataset
from utils.visualisation import * 
folder_path = os.path.dirname(os.getcwd())

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
code_path= os.getcwd()
folder_path = os.path.dirname(os.getcwd())
data_path = os.path.join(folder_path, 'Data','oxford-iiit-pet' )
list_path  = os.path.join(data_path, 'annotations', 'list.txt')
image_path = os.path.join(data_path, 'images')
mask_path = os.path.join(data_path, 'annotations', 'trimaps')
frame_path = os.path.join(data_path, 'annotations', 'xmls')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using device: cuda

# %%
catdog_dataset = DogCatDataset(image_path= image_path, label_path= list_paths,mask_path= mask_path, frame_path= frame_path)
len(catdog_dataset)
# Out:
# This dataset has 7349 samples.
# 7349

# %%
catdog_dataset[4]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 catdog_dataset[4]
#
# File c:\Users\anhqu\Desktop\Anh Quan\5GMM\Project HDDL\Code\utils\dataset.py:60, in __getitem__(self, idx)
#      58 image_path = os.path.join(self.image_path, image_name + '.jpg')
#      59 image = Image.open(image_path).convert('RGB')
# ---> 60 mask_path = self.mask_path
#      63 frame_path = os.path.join(self.frame_path, image_name +'.xml' )
#      64 anno = Anonotation(frame_path)
#
# File c:\Users\anhqu\Desktop\Anh Quan\5GMM\Project HDDL\Code\utils\dataset.py:8, in __init__(self, filename)
#       6 import xml.etree.ElementTree as ET
#       7 import cv2
# ----> 8 class Anonotation:
#       9     def __init__(self, filename):
#      10         self.filename = filename
#
# ...

# %%
show_image(*catdog_dataset[7])

# %%
files = os.listdir(image_path)
print(len(files))
# Out:
# 7393
